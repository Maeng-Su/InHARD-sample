# %%
import os
import pandas as pd
import subprocess
import xml.etree.ElementTree as ET
import re

# %%
#======================================================================
# 1. 사용자 설정
#======================================================================

# GT 정보가 담긴 Anvil 파일
anvil_file = './sample data/P01_R01.anvil'

# 클립을 생성할 원본 영상들이 있는 디렉토리
# (이전 단계에서 P01_R01.mp4를 V1~V4로 분할한 영상이 담긴 폴더)
source_video_dir = 'split_videos'

# 생성된 클립들을 저장할 최상위 디렉토리
output_clips_basedir = 'gt_clips'

# 파싱할 GT 트랙 이름 ("Action Label" 또는 "Meta-Action Label")
# "Action Label"이 더 세분화된 행동 정보를 포함합니다.
track_name_to_parse = "Meta-Action Label"

# %%
#======================================================================
# 2. Anvil 파일 파싱 함수 (사용자 코드 재활용)
#======================================================================

def parse_anvil_track(anvil_file, track_name):
    """
    지정된 .anvil 파일에서 특정 트랙 이름의 주석(annotation)을 파싱하여
    Pandas DataFrame으로 반환하는 함수.
    """
    if not os.path.exists(anvil_file):
        print(f"[오류] Anvil 파일 '{anvil_file}'을 찾을 수 없습니다.")
        return None

    try:
        tree = ET.parse(anvil_file)
        root = tree.getroot()
        annotations = []
        target_track = root.find(f'.//track[@name="{track_name}"]')

        if target_track is None:
            print(f"[정보] '{track_name}' 트랙을 찾을 수 없습니다.")
            return None

        for element in target_track.findall('el'):
            start_time = element.get('start')
            end_time = element.get('end')
            attribute = element.find('attribute')
            if attribute is not None and attribute.text:
                action_label = attribute.text
                annotations.append({
                    'Label': action_label,
                    'Start Time (s)': float(start_time),
                    'End Time (s)': float(end_time)
                })
        return pd.DataFrame(annotations)

    except ET.ParseError as e:
        print(f"[오류] XML 파일을 파싱하는 중 오류가 발생했습니다: {e}")
        return None
    except Exception as e:
        print(f"알 수 없는 오류가 발생했습니다: {e}")
        return None

# %%
#======================================================================
# 3. 메인 실행 로직
#======================================================================

# --- GT 데이터 로드 ---
print(f"'{anvil_file}'에서 '{track_name_to_parse}' 트랙 정보를 읽어옵니다...")
gt_df = parse_anvil_track(anvil_file, track_name_to_parse)

if gt_df is None or gt_df.empty:
    print("[실패] GT 데이터를 불러오지 못했습니다. 스크립트를 종료합니다.")
else:
    print(f"총 {len(gt_df)}개의 행동(클립)을 발견했습니다.")
    
    # --- 클리핑할 원본 영상 목록 가져오기 ---
    source_videos = sorted([f for f in os.listdir(source_video_dir) if f.endswith('.mp4')])
    if not source_videos:
        print(f"[오류] '{source_video_dir}' 폴더에 처리할 영상 파일이 없습니다.")
    else:
        print(f"다음 원본 영상들에 대해 클리핑을 시작합니다: {source_videos}")
# Out:
# './sample data/P01_R01.anvil'에서 'Meta-Action Label' 트랙 정보를 읽어옵니다...
# 총 109개의 행동(클립)을 발견했습니다.
# 다음 원본 영상들에 대해 클리핑을 시작합니다: ['P01_R01_V1.mp4', 'P01_R01_V2.mp4', 'P01_R01_V3.mp4', 'P01_R01_V4.mp4']

# %%
gt_df
# Out:
#                         Label  Start Time (s)  End Time (s)
# 0          [2] Consult sheets         2.72000       9.00000
# 1            [7] Picking left        11.28000      12.84000
# 2        [12] Assemble system        13.84000      18.88000
# 3        [6] Picking in front        23.32000      25.44000
# 4        [12] Assemble system        26.48000      28.80000
# ..                        ...             ...           ...
# 104      [12] Assemble system       492.88000     497.88000
# 105      [4] Take screwdriver       504.64001     506.16000
# 106      [12] Assemble system       506.39999     509.79999
# 107  [5] Put down screwdriver       509.88000     512.08002
# 108   [14] Put down subsystem       515.00000     523.28003
#
# [109 rows x 3 columns]

# %%
# --- 각 GT 항목에 대해 영상 클리핑 실행 ---
for index, row in gt_df.iterrows():
    label = row['Label']
    start_time = row['Start Time (s)']
    end_time = row['End Time (s)']
    duration = end_time - start_time

    # 파일명으로 사용할 수 없는 문자 제거 및 공백을 언더스코어로 변경
    sanitized_label = re.sub(r'[\\/*?:"<>|]', "", label).replace(' ', '_')
    
    # 클립을 저장할 하위 폴더 생성 (예: gt_clips/001_[OP010]_Consult_sheets/)
    clip_subdir_name = f"{index:03d}_{sanitized_label}"
    clip_output_path = os.path.join(output_clips_basedir, clip_subdir_name)
    os.makedirs(clip_output_path, exist_ok=True)
    
    print(f"\n[{index+1}/{len(gt_df)}] '{label}' 클립 생성 중...")
    print(f"  - 시간: {start_time:.2f}s ~ {end_time:.2f}s (길이: {duration:.2f}s)")
    print(f"  - 저장 위치: {clip_output_path}")

    # 각 뷰(V1~V4) 영상에 대해 클리핑 작업 수행
    for video_file in source_videos:
        input_path = os.path.join(source_video_dir, video_file)
        
        # 출력 파일명 설정 (예: clip_V1.mp4)
        view_name = os.path.splitext(video_file)[0].split('_')[-1] # V1, V2 등 추출
        output_filename = f"clip_{view_name}.mp4"
        output_path = os.path.join(clip_output_path, output_filename)

        # FFmpeg 명령어 생성
        # -c copy 옵션: 재인코딩 없이 원본 스트림을 그대로 복사하여 매우 빠릅니다.
        command = [
            'ffmpeg',
            '-y',                      # 덮어쓰기 허용
            '-i', input_path,          # 입력 파일
            '-ss', str(start_time),    # 시작 시간
            '-t', str(duration),       # 지속 시간
            # '-c', 'copy',              # 코덱 복사 (빠른 속도)
            output_path
        ]

        try:
            # FFmpeg 실행
            subprocess.run(command, check=True, capture_output=True, text=True)
        except FileNotFoundError:
            print("[치명적 오류] FFmpeg가 설치되어 있지 않거나 경로가 설정되지 않았습니다. 스크립트를 중단합니다.")
            exit()
        except subprocess.CalledProcessError as e:
            print(f"[오류] {video_file} 처리 중 FFmpeg 오류 발생:\n-> {e.stderr}")
            continue

print(f"\n🎉 모든 영상 클리핑 작업이 완료되었습니다!")
print(f"-> 최종 결과는 '{output_clips_basedir}' 폴더를 확인해주세요.")
# Out:
# [1/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 2.72s ~ 9.00s (길이: 6.28s)
#   - 저장 위치: gt_clips/000_[2]_Consult_sheets
#
# [2/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 11.28s ~ 12.84s (길이: 1.56s)
#   - 저장 위치: gt_clips/001_[7]_Picking_left
#
# [3/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 13.84s ~ 18.88s (길이: 5.04s)
#   - 저장 위치: gt_clips/002_[12]_Assemble_system
#
# [4/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 23.32s ~ 25.44s (길이: 2.12s)
#   - 저장 위치: gt_clips/003_[6]_Picking_in_front
#
# [5/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 26.48s ~ 28.80s (길이: 2.32s)
#   - 저장 위치: gt_clips/004_[12]_Assemble_system
#
# [6/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 31.24s ~ 32.40s (길이: 1.16s)
#   - 저장 위치: gt_clips/005_[7]_Picking_left
#
# [7/109] '[8] Take measuring rod' 클립 생성 중...
#   - 시간: 36.56s ~ 37.92s (길이: 1.36s)
#   - 저장 위치: gt_clips/006_[8]_Take_measuring_rod
#
# [8/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 39.36s ~ 40.40s (길이: 1.04s)
#   - 저장 위치: gt_clips/007_[4]_Take_screwdriver
#
# [9/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 41.20s ~ 44.56s (길이: 3.36s)
#   - 저장 위치: gt_clips/008_[12]_Assemble_system
#
# [10/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 44.76s ~ 47.24s (길이: 2.48s)
#   - 저장 위치: gt_clips/009_[5]_Put_down_screwdriver
#
# [11/109] '[9] Put down measuring rod' 클립 생성 중...
#   - 시간: 47.28s ~ 49.12s (길이: 1.84s)
#   - 저장 위치: gt_clips/010_[9]_Put_down_measuring_rod
#
# [12/109] '[3] Turn sheets' 클립 생성 중...
#   - 시간: 54.52s ~ 57.52s (길이: 3.00s)
#   - 저장 위치: gt_clips/011_[3]_Turn_sheets
#
# [13/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 57.56s ~ 58.12s (길이: 0.56s)
#   - 저장 위치: gt_clips/012_[2]_Consult_sheets
#
# [14/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 58.76s ~ 60.64s (길이: 1.88s)
#   - 저장 위치: gt_clips/013_[7]_Picking_left
#
# [15/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 61.08s ~ 66.28s (길이: 5.20s)
#   - 저장 위치: gt_clips/014_[12]_Assemble_system
#
# [16/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 66.56s ~ 69.32s (길이: 2.76s)
#   - 저장 위치: gt_clips/015_[7]_Picking_left
#
# [17/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 69.88s ~ 72.04s (길이: 2.16s)
#   - 저장 위치: gt_clips/016_[6]_Picking_in_front
#
# [18/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 73.56s ~ 81.96s (길이: 8.40s)
#   - 저장 위치: gt_clips/017_[12]_Assemble_system
#
# [19/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 82.24s ~ 83.28s (길이: 1.04s)
#   - 저장 위치: gt_clips/018_[4]_Take_screwdriver
#
# [20/109] '[8] Take measuring rod' 클립 생성 중...
#   - 시간: 84.52s ~ 86.88s (길이: 2.36s)
#   - 저장 위치: gt_clips/019_[8]_Take_measuring_rod
#
# [21/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 87.72s ~ 92.00s (길이: 4.28s)
#   - 저장 위치: gt_clips/020_[12]_Assemble_system
#
# [22/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 92.32s ~ 93.04s (길이: 0.72s)
#   - 저장 위치: gt_clips/021_[5]_Put_down_screwdriver
#
# [23/109] '[9] Put down measuring rod' 클립 생성 중...
#   - 시간: 93.12s ~ 95.44s (길이: 2.32s)
#   - 저장 위치: gt_clips/022_[9]_Put_down_measuring_rod
#
# [24/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 107.12s ~ 110.04s (길이: 2.92s)
#   - 저장 위치: gt_clips/023_[2]_Consult_sheets
#
# [25/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 111.12s ~ 112.80s (길이: 1.68s)
#   - 저장 위치: gt_clips/024_[7]_Picking_left
#
# [26/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 116.88s ~ 118.84s (길이: 1.96s)
#   - 저장 위치: gt_clips/025_[12]_Assemble_system
#
# [27/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 124.48s ~ 128.64s (길이: 4.16s)
#   - 저장 위치: gt_clips/026_[6]_Picking_in_front
#
# [28/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 130.00s ~ 134.60s (길이: 4.60s)
#   - 저장 위치: gt_clips/027_[12]_Assemble_system
#
# [29/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 136.44s ~ 138.60s (길이: 2.16s)
#   - 저장 위치: gt_clips/028_[6]_Picking_in_front
#
# [30/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 138.76s ~ 141.00s (길이: 2.24s)
#   - 저장 위치: gt_clips/029_[12]_Assemble_system
#
# [31/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 143.88s ~ 145.52s (길이: 1.64s)
#   - 저장 위치: gt_clips/030_[7]_Picking_left
#
# [32/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 148.16s ~ 148.80s (길이: 0.64s)
#   - 저장 위치: gt_clips/031_[4]_Take_screwdriver
#
# [33/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 148.88s ~ 153.16s (길이: 4.28s)
#   - 저장 위치: gt_clips/032_[12]_Assemble_system
#
# [34/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 153.24s ~ 155.60s (길이: 2.36s)
#   - 저장 위치: gt_clips/033_[5]_Put_down_screwdriver
#
# [35/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 156.88s ~ 159.16s (길이: 2.28s)
#   - 저장 위치: gt_clips/034_[6]_Picking_in_front
#
# [36/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 160.00s ~ 164.36s (길이: 4.36s)
#   - 저장 위치: gt_clips/035_[2]_Consult_sheets
#
# [37/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 165.80s ~ 168.12s (길이: 2.32s)
#   - 저장 위치: gt_clips/036_[12]_Assemble_system
#
# [38/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 171.08s ~ 172.68s (길이: 1.60s)
#   - 저장 위치: gt_clips/037_[7]_Picking_left
#
# [39/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 173.44s ~ 175.44s (길이: 2.00s)
#   - 저장 위치: gt_clips/038_[12]_Assemble_system
#
# [40/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 176.36s ~ 178.16s (길이: 1.80s)
#   - 저장 위치: gt_clips/039_[6]_Picking_in_front
#
# [41/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 179.04s ~ 183.36s (길이: 4.32s)
#   - 저장 위치: gt_clips/040_[12]_Assemble_system
#
# [42/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 184.88s ~ 186.32s (길이: 1.44s)
#   - 저장 위치: gt_clips/041_[6]_Picking_in_front
#
# [43/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 186.64s ~ 187.60s (길이: 0.96s)
#   - 저장 위치: gt_clips/042_[12]_Assemble_system
#
# [44/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 188.20s ~ 189.96s (길이: 1.76s)
#   - 저장 위치: gt_clips/043_[7]_Picking_left
#
# [45/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 191.36s ~ 193.08s (길이: 1.72s)
#   - 저장 위치: gt_clips/044_[4]_Take_screwdriver
#
# [46/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 193.84s ~ 196.24s (길이: 2.40s)
#   - 저장 위치: gt_clips/045_[12]_Assemble_system
#
# [47/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 196.56s ~ 198.60s (길이: 2.04s)
#   - 저장 위치: gt_clips/046_[5]_Put_down_screwdriver
#
# [48/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 199.16s ~ 200.84s (길이: 1.68s)
#   - 저장 위치: gt_clips/047_[6]_Picking_in_front
#
# [49/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 201.48s ~ 204.80s (길이: 3.32s)
#   - 저장 위치: gt_clips/048_[12]_Assemble_system
#
# [50/109] '[14] Put down subsystem' 클립 생성 중...
#   - 시간: 217.52s ~ 224.40s (길이: 6.88s)
#   - 저장 위치: gt_clips/049_[14]_Put_down_subsystem
#
# [51/109] '[3] Turn sheets' 클립 생성 중...
#   - 시간: 242.24s ~ 245.40s (길이: 3.16s)
#   - 저장 위치: gt_clips/050_[3]_Turn_sheets
#
# [52/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 245.52s ~ 246.68s (길이: 1.16s)
#   - 저장 위치: gt_clips/051_[2]_Consult_sheets
#
# [53/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 247.88s ~ 251.24s (길이: 3.36s)
#   - 저장 위치: gt_clips/052_[6]_Picking_in_front
#
# [54/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 257.12s ~ 259.20s (길이: 2.08s)
#   - 저장 위치: gt_clips/053_[7]_Picking_left
#
# [55/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 259.80s ~ 266.04s (길이: 6.24s)
#   - 저장 위치: gt_clips/054_[12]_Assemble_system
#
# [56/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 266.44s ~ 267.76s (길이: 1.32s)
#   - 저장 위치: gt_clips/055_[4]_Take_screwdriver
#
# [57/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 268.24s ~ 271.00s (길이: 2.76s)
#   - 저장 위치: gt_clips/056_[12]_Assemble_system
#
# [58/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 271.04s ~ 272.56s (길이: 1.52s)
#   - 저장 위치: gt_clips/057_[5]_Put_down_screwdriver
#
# [59/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 275.16s ~ 277.12s (길이: 1.96s)
#   - 저장 위치: gt_clips/058_[2]_Consult_sheets
#
# [60/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 284.36s ~ 286.80s (길이: 2.44s)
#   - 저장 위치: gt_clips/059_[6]_Picking_in_front
#
# [61/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 294.92s ~ 296.68s (길이: 1.76s)
#   - 저장 위치: gt_clips/060_[7]_Picking_left
#
# [62/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 296.76s ~ 299.48s (길이: 2.72s)
#   - 저장 위치: gt_clips/061_[12]_Assemble_system
#
# [63/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 299.72s ~ 301.52s (길이: 1.80s)
#   - 저장 위치: gt_clips/062_[7]_Picking_left
#
# [64/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 302.08s ~ 304.12s (길이: 2.04s)
#   - 저장 위치: gt_clips/063_[12]_Assemble_system
#
# [65/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 308.36s ~ 309.76s (길이: 1.40s)
#   - 저장 위치: gt_clips/064_[7]_Picking_left
#
# [66/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 316.56s ~ 317.76s (길이: 1.20s)
#   - 저장 위치: gt_clips/065_[4]_Take_screwdriver
#
# [67/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 318.20s ~ 320.80s (길이: 2.60s)
#   - 저장 위치: gt_clips/066_[12]_Assemble_system
#
# [68/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 320.92s ~ 322.96s (길이: 2.04s)
#   - 저장 위치: gt_clips/067_[5]_Put_down_screwdriver
#
# [69/109] '[3] Turn sheets' 클립 생성 중...
#   - 시간: 330.04s ~ 333.76s (길이: 3.72s)
#   - 저장 위치: gt_clips/068_[3]_Turn_sheets
#
# [70/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 333.84s ~ 335.44s (길이: 1.60s)
#   - 저장 위치: gt_clips/069_[6]_Picking_in_front
#
# [71/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 337.40s ~ 339.92s (길이: 2.52s)
#   - 저장 위치: gt_clips/070_[7]_Picking_left
#
# [72/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 349.00s ~ 350.80s (길이: 1.80s)
#   - 저장 위치: gt_clips/071_[12]_Assemble_system
#
# [73/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 351.24s ~ 353.20s (길이: 1.96s)
#   - 저장 위치: gt_clips/072_[7]_Picking_left
#
# [74/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 353.92s ~ 355.44s (길이: 1.52s)
#   - 저장 위치: gt_clips/073_[12]_Assemble_system
#
# [75/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 355.84s ~ 358.56s (길이: 2.72s)
#   - 저장 위치: gt_clips/074_[12]_Assemble_system
#
# [76/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 361.40s ~ 363.44s (길이: 2.04s)
#   - 저장 위치: gt_clips/075_[7]_Picking_left
#
# [77/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 370.12s ~ 371.16s (길이: 1.04s)
#   - 저장 위치: gt_clips/076_[4]_Take_screwdriver
#
# [78/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 372.20s ~ 374.60s (길이: 2.40s)
#   - 저장 위치: gt_clips/077_[12]_Assemble_system
#
# [79/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 374.80s ~ 376.48s (길이: 1.68s)
#   - 저장 위치: gt_clips/078_[5]_Put_down_screwdriver
#
# [80/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 381.88s ~ 383.68s (길이: 1.80s)
#   - 저장 위치: gt_clips/079_[2]_Consult_sheets
#
# [81/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 384.24s ~ 386.72s (길이: 2.48s)
#   - 저장 위치: gt_clips/080_[7]_Picking_left
#
# [82/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 389.20s ~ 392.24s (길이: 3.04s)
#   - 저장 위치: gt_clips/081_[12]_Assemble_system
#
# [83/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 393.48s ~ 395.00s (길이: 1.52s)
#   - 저장 위치: gt_clips/082_[6]_Picking_in_front
#
# [84/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 397.72s ~ 399.76s (길이: 2.04s)
#   - 저장 위치: gt_clips/083_[7]_Picking_left
#
# [85/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 402.20s ~ 408.92s (길이: 6.72s)
#   - 저장 위치: gt_clips/084_[12]_Assemble_system
#
# [86/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 409.08s ~ 410.40s (길이: 1.32s)
#   - 저장 위치: gt_clips/085_[4]_Take_screwdriver
#
# [87/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 411.20s ~ 413.32s (길이: 2.12s)
#   - 저장 위치: gt_clips/086_[12]_Assemble_system
#
# [88/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 413.40s ~ 417.04s (길이: 3.64s)
#   - 저장 위치: gt_clips/087_[5]_Put_down_screwdriver
#
# [89/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 417.40s ~ 418.64s (길이: 1.24s)
#   - 저장 위치: gt_clips/088_[2]_Consult_sheets
#
# [90/109] '[3] Turn sheets' 클립 생성 중...
#   - 시간: 421.28s ~ 423.16s (길이: 1.88s)
#   - 저장 위치: gt_clips/089_[3]_Turn_sheets
#
# [91/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 424.04s ~ 426.40s (길이: 2.36s)
#   - 저장 위치: gt_clips/090_[2]_Consult_sheets
#
# [92/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 426.64s ~ 428.96s (길이: 2.32s)
#   - 저장 위치: gt_clips/091_[6]_Picking_in_front
#
# [93/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 429.44s ~ 430.84s (길이: 1.40s)
#   - 저장 위치: gt_clips/092_[12]_Assemble_system
#
# [94/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 431.48s ~ 433.00s (길이: 1.52s)
#   - 저장 위치: gt_clips/093_[7]_Picking_left
#
# [95/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 434.92s ~ 436.84s (길이: 1.92s)
#   - 저장 위치: gt_clips/094_[4]_Take_screwdriver
#
# [96/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 437.40s ~ 439.88s (길이: 2.48s)
#   - 저장 위치: gt_clips/095_[12]_Assemble_system
#
# [97/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 439.96s ~ 442.12s (길이: 2.16s)
#   - 저장 위치: gt_clips/096_[5]_Put_down_screwdriver
#
# [98/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 442.24s ~ 443.52s (길이: 1.28s)
#   - 저장 위치: gt_clips/097_[2]_Consult_sheets
#
# [99/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 460.12s ~ 461.92s (길이: 1.80s)
#   - 저장 위치: gt_clips/098_[7]_Picking_left
#
# [100/109] '[6] Picking in front' 클립 생성 중...
#   - 시간: 464.96s ~ 467.00s (길이: 2.04s)
#   - 저장 위치: gt_clips/099_[6]_Picking_in_front
#
# [101/109] '[2] Consult sheets' 클립 생성 중...
#   - 시간: 468.60s ~ 471.20s (길이: 2.60s)
#   - 저장 위치: gt_clips/100_[2]_Consult_sheets
#
# [102/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 471.56s ~ 473.16s (길이: 1.60s)
#   - 저장 위치: gt_clips/101_[12]_Assemble_system
#
# [103/109] '[7] Picking left' 클립 생성 중...
#   - 시간: 478.16s ~ 480.48s (길이: 2.32s)
#   - 저장 위치: gt_clips/102_[7]_Picking_left
#
# [104/109] '[13] Take subsystem' 클립 생성 중...
#   - 시간: 480.80s ~ 482.80s (길이: 2.00s)
#   - 저장 위치: gt_clips/103_[13]_Take_subsystem
#
# [105/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 492.88s ~ 497.88s (길이: 5.00s)
#   - 저장 위치: gt_clips/104_[12]_Assemble_system
#
# [106/109] '[4] Take screwdriver' 클립 생성 중...
#   - 시간: 504.64s ~ 506.16s (길이: 1.52s)
#   - 저장 위치: gt_clips/105_[4]_Take_screwdriver
#
# [107/109] '[12] Assemble system' 클립 생성 중...
#   - 시간: 506.40s ~ 509.80s (길이: 3.40s)
#   - 저장 위치: gt_clips/106_[12]_Assemble_system
#
# [108/109] '[5] Put down screwdriver' 클립 생성 중...
#   - 시간: 509.88s ~ 512.08s (길이: 2.20s)
#   - 저장 위치: gt_clips/107_[5]_Put_down_screwdriver
#
# [109/109] '[14] Put down subsystem' 클립 생성 중...
#   - 시간: 515.00s ~ 523.28s (길이: 8.28s)
#   - 저장 위치: gt_clips/108_[14]_Put_down_subsystem
#
# 🎉 모든 영상 클리핑 작업이 완료되었습니다!
# -> 최종 결과는 'gt_clips' 폴더를 확인해주세요.
